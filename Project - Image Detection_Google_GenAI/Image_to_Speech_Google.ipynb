# %%
 ! pip install google-genai
# Out:
# Requirement already satisfied: google-genai in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (1.63.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-genai) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.48.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-genai) (2.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.6.2)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (3.0)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google import genai

#f = open("keys/.gemini.txt")
#key = f.read()

client = genai.Client(api_key="AIzaSyDywbDlFJsNr6Olf-RLLuzlMY-xjUrLQ5Q")

# %%
from google import genai
from google.genai import types

custom_config = types.GenerateContentConfig(
    system_instruction="You are a helpful AI Assistant. Given an image perform object detection and provide a text output which contains the information about the labels detected and their counts.",
    temperature=1,
    top_p=0.8,
)

with open('images/image_2.jpeg', 'rb') as f:
  image_bytes = f.read()

context = [
    types.Part.from_bytes(
        data=image_bytes,
        mime_type='image/jpeg',
    ),
]

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=context,
    config = custom_config
)

print(response.text)
# Out:
# The image holds 44 cars, 4 buses, 1 truck, 1 motorcycle, and 1 person.

# %%
from transformers import pipeline
narrator = pipeline(
    task="text-to-speech",
    model="suno/bark-small",
)
narrated_text = narrator(response.text)
print(narrated_text["sampling_rate"])
# Out:
# Loading weights:   0%|          | 0/542 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.1.weight to fine_acoustics.lm_heads.0.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.2.weight to fine_acoustics.lm_heads.1.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.3.weight to fine_acoustics.lm_heads.2.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.4.weight to fine_acoustics.lm_heads.3.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.5.weight to fine_acoustics.lm_heads.4.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.6.weight to fine_acoustics.lm_heads.5.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.7.weight to fine_acoustics.lm_heads.6.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Passing `generation_config` together with generation-related arguments=({'min_eos_p', 'return_dict_in_generate'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Both `max_new_tokens` (=768) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens', 'return_dict_in_generate'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=24) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 24000

# %%
#!pip install --upgrade transformers scipy
! pip install datasets soundfile librosa
# Out:
# Requirement already satisfied: datasets in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (4.5.0)
# Requirement already satisfied: soundfile in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (0.13.1)
# Requirement already satisfied: librosa in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (0.11.0)
# Requirement already satisfied: filelock in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (3.20.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (2.3.5)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (3.0.0)
# Requirement already satisfied: requests>=2.32.2 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (1.4.1)
# Requirement already satisfied: packaging in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.23.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from soundfile) (2.0.0)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from librosa) (0.63.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from librosa) (1.17.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from librosa) (1.8.0)
# Requirement already satisfied: joblib>=1.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from librosa) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from librosa) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from librosa) (1.1.2)
# Requirement already satisfied: standard-aifc in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from librosa) (3.13.0)
# Requirement already satisfied: standard-sunau in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from librosa) (3.13.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: pycparser in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from cffi>=1.0->soundfile) (3.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from numba>=0.51.0->librosa) (0.46.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from pooch>=1.1->librosa) (4.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: colorama in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: standard-chunk in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from standard-aifc->librosa) (3.13.0)
# Requirement already satisfied: audioop-lts in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from standard-aifc->librosa) (0.2.2)
# Requirement already satisfied: typer>=0.23.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.23.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from typer>=0.23.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (8.3.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from typer>=0.23.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from typer>=0.23.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from rich>=10.11.0->typer>=0.23.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from rich>=10.11.0->typer>=0.23.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sra\onedrive - hexagon\desktop\hands on ai\langflow_test_lab\.env_google\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import scipy
scipy.io.wavfile.write("bark_out.wav", rate=narrated_text["sampling_rate"], data=narrated_text["audio"])

# %%
from IPython.display import Audio as IPythonAudio

IPythonAudio(
    narrated_text["audio"],
    rate=narrated_text["sampling_rate"]
)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
